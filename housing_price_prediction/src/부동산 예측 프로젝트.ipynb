# %% [markdown]
# 데이터세트 일부 처리

# %%
import pandas as pd #Analysis 
import matplotlib.pyplot as plt #Visulization
import seaborn as sns #Visulization
import numpy as np #Analysis 
from scipy.stats import norm #Analysis 
from sklearn.preprocessing import StandardScaler #Analysis 
from scipy import stats #Analysis 
import warnings 
warnings.filterwarnings('ignore')
# %matplotlib inline

from sklearn.model_selection import KFold
import sklearn.model_selection
from sklearn.metrics import mean_absolute_error
import gc
import lightgbm as lgb

from sklearn.metrics import mean_squared_error
from sklearn.linear_model import BayesianRidge

# %%
# !pwd
# Out:
# /Users/lyuhoyun/Documents/GitHub/Business_analytics/housing_price_prediction/src

# %%
train_df = pd.read_csv('../../../git_ignore_file/dataset/housing-price-prediction/train_seoul_3th.csv',encoding='UTF-8')


##if : data == xlxs
#train_df = pd.read_excel('train_seoul_3th.xlsx')

# %%
train_df
# Out:
#         transaction_id  apartment_id dong    jibun        apt  \
# 0                    0          7622  신교동  06월 13일   신현(101동)
# 1                    1          5399  필운동      142     사직파크맨션
# 2                    2          3578  필운동    174-1     두레엘리시안
# 3                    3         10957  내수동       95      파크팰리스
# 4                    4         10639  내수동   110-15       킹스매너
# ...                ...           ...  ...      ...        ...
# 742280         1196844           996  강일동      717  고덕리엔파크2단지
# 742281         1196846           682  강일동      674  강일리버파크3단지
# 742282         1196847           682  강일동      674  강일리버파크3단지
# 742283         1196848           680  강일동      665  강일리버파크1단지
# 742284         1196849           996  강일동      717  고덕리엔파크2단지
#
#                   addr_kr  exclusive_use_area  year_of_completion  \
# 0       신교동 6-13 신현(101동)               84.82                2002
# 1          필운동 142 사직파크맨션               99.17                1973
# 2        필운동 174-1 두레엘리시안               84.74                2007
# 3            내수동 95 파크팰리스              146.39                2003
# 4         내수동 110-15 킹스매너              194.43                2004
# ...                   ...                 ...                 ...
# 742280  강일동 717 고덕리엔파크2단지               59.72                2011
# 742281  강일동 674 강일리버파크3단지               59.87                2009
# 742282  강일동 674 강일리버파크3단지               84.74                2009
# 742283  강일동 665 강일리버파크1단지               84.74                2009
# 742284  강일동 717 고덕리엔파크2단지               84.98                2011
#
#         transaction_year_month transaction_date  ...  CBD  park  address_gu  \
# 0                       200801            21~31  ...    1    12         종로구
# 1                       200801             1~10  ...    1    12         종로구
# 2                       200801             1~10  ...    1    12         종로구
# 3                       200801            11~20  ...    1    12         종로구
# 4                       200801            21~31  ...    1    12         종로구
# ...                        ...              ...  ...  ...   ...         ...
# 742280                  201711            11~20  ...    0     7         강동구
# 742281                  201711            21~30  ...    0     7         강동구
# 742282                  201711            21~30  ...    0     7         강동구
# 742283                  201711            21~30  ...    0     7         강동구
# 742284                  201711            21~30  ...    0     7         강동구
#
#         price/area  base_money_rate number_of_subway_stations  \
# 0       442.112709            5.450                        15
# 1       201.673893            5.450                        15
# 2       454.330894            5.450                        15
# 3       806.065988            5.450                        15
# 4       617.188705            5.450                        15
# ...            ...              ...                       ...
# 742280  887.474883            1.362                        14
# 742281  885.251378            1.362                        14
# 742282  666.745339            1.362                        14
# 742283  654.944536            1.362                        14
# 742284  750.176512            1.362                        14
#
#         department_stores  the_number_of_elementary_schools  \
# 0                       0                                39
# 1                       0                                39
# 2                       0                                39
# 3                       0                                39
# 4                       0                                39
# ...                   ...                               ...
# 742280                  0                                70
# 742281                  0                                70
# 742282                  0                                70
# 742283                  0                                70
# 742284                  0                                70
#
#         the_number_of_middle_school  the_number_of_special_purpose_high_school
# 0                                25                                          1
# 1                                25                                          1
# 2                                25                                          1
# 3                                25                                          1
# 4                                25                                          1
# ...                             ...                                        ...
# 742280                           48                                          0
# 742281                           48                                          0
# 742282                           48                                          0
# 742283                           48                                          0
# 742284                           48                                          0
#
# [742285 rows x 23 columns]

# %%
#상관관계 확인
k=train_df.shape[1] #히트맵 변수 갯수
corrmat = train_df.corr() #변수간의 상관관계
cols = corrmat.nlargest(k, 'transaction_real_price')['transaction_real_price'].index #price기준으로 제일 큰순서대로 20개를 뽑아냄
cm = np.corrcoef(train_df[cols].values.T)
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(data = cm, annot=True, square=True, fmt = '.2f', linewidths=.5, cmap='Reds', 
            yticklabels = cols.values, xticklabels = cols.values)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 #상관관계 확인
#       2 k=train_df.shape[1] #히트맵 변수 갯수
# ----> 3 corrmat = train_df.corr() #변수간의 상관관계
#       4 cols = corrmat.nlargest(k, 'transaction_real_price')['transaction_real_price'].index #price기준으로 제일 큰순서대로 20개를 뽑아냄
#       5 cm = np.corrcoef(train_df[cols].values.T)
#
# File /opt/anaconda3/envs/data_venv/lib/python3.8/site-packages/pandas/core/frame.py:10054, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10052 cols = data.columns
#   10053 idx = cols.copy()
# > 10054 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10056 if method == "pearson":
#   10057     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File /opt/anaconda3/envs/data_venv/lib/python3.8/site-packages/pandas/core/frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# File /opt/anaconda3/envs/data_venv/lib/python3.8/site-packages/pandas/core/internals/managers.py:1732, in BlockManager.as_array(self, dtype, copy, na_value)
#    1730         arr.flags.writeable = False
#    1731 else:
# -> 1732     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1733     # The underlying data was copied within _interleave, so no need
#    1734     # to further copy if copy=True or setting na_value
#    1736 if na_value is not lib.no_default:
#
# File /opt/anaconda3/envs/data_venv/lib/python3.8/site-packages/pandas/core/internals/managers.py:1794, in BlockManager._interleave(self, dtype, na_value)
#    1792     else:
#    1793         arr = blk.get_values(dtype)
# -> 1794     result[rl.indexer] = arr
#    1795     itemmask[rl.indexer] = 1
#    1797 if not itemmask.all():
#
# ValueError: could not convert string to float: '신교동'

# %%
train_df['floor'].astype(int)
train_df['transaction_real_price'].astype(int)




train_dong = train_df[['transaction_real_price','dong']].groupby('dong').mean().sort_values('transaction_real_price').reset_index()

dong_num = {}
for i in range(len(train_dong)):
    dong = train_dong['dong'].iloc[i]
    dong_num[dong] = i
    



train_set,test_set = sklearn.model_selection.train_test_split(train_df,random_state=40)

train_set = train_set.replace({'dong' : dong_num})
test_set = test_set.replace({'dong' : dong_num})


train_jibun = train_set[['transaction_real_price','jibun']].groupby('jibun').mean().sort_values('transaction_real_price').reset_index()
train_set['day_diff'] = train_set['transaction_date'].str.extract('(~\d+)')[0].str[1:].astype(int) - train_set['transaction_date'].str.extract('(\d+~)')[0].str[:-1].astype(int)
test_set['day_diff'] = test_set['transaction_date'].str.extract('(~\d+)')[0].str[1:].astype(int) - test_set['transaction_date'].str.extract('(\d+~)')[0].str[:-1].astype(int)

train_date = train_set[['transaction_real_price','transaction_date']].groupby('transaction_date').mean().sort_values('transaction_real_price').reset_index()

date_num = {}
for i in range(len(train_date)):
    date = train_date['transaction_date'].iloc[i]
    date_num[date] = i
    
train_set = train_set.replace({'transaction_date' : date_num})
test_set = test_set.replace({'transaction_date' : date_num})


train_test_data = [train_set, test_set]

for dataset in train_test_data:
    #date -> 년, 월 단위로 새로운 칼럼 만듦
    dataset['transaction_year_month'] = dataset['transaction_year_month'].astype(str)
    dataset['year'] = dataset['transaction_year_month'].str[:4].astype(int)
    dataset['month'] = dataset['transaction_year_month'].str[4:6].astype(int)
    dataset['transaction_year_month'] = dataset['transaction_year_month'].astype(int)


train_test_data = [train_set, test_set]

for dataset in train_test_data:
    # 거래하는 기간까지의 아파트 나이를 feature 생성
    dataset['age'] = dataset['year'] - dataset['year_of_completion']
    # 샘플코드에 있는 아파트의 재건축 유무를 판단하는 feature 생성
    dataset['is_rebuild']=(dataset['age']>=30).astype(int)


train_set=train_set.drop(labels=['apt','addr_kr','jibun','address_gu'],axis=1)
test_set=test_set.drop(labels=['apt','addr_kr','jibun','address_gu'],axis=1)
train_set['floor'].loc[train_set['floor']<0]=0


train_set['special_high_school'] = train_set['the_number_of_special_purpose_high_school']
train_set['middle_school'] = train_set['the_number_of_middle_school']
train_set['elementary_schools'] = train_set['the_number_of_elementary_schools']
train_set=train_set.drop(labels=['the_number_of_special_purpose_high_school','the_number_of_middle_school','the_number_of_elementary_schools'],axis=1)

test_set['special_high_school'] = test_set['the_number_of_special_purpose_high_school']
test_set['middle_school'] = test_set['the_number_of_middle_school']
test_set['elementary_schools'] = test_set['the_number_of_elementary_schools']
test_set=test_set.drop(labels=['the_number_of_special_purpose_high_school','the_number_of_middle_school','the_number_of_elementary_schools'],axis=1)

# %%
train_set
# Out:
#         transaction_id  apartment_id  dong  exclusive_use_area  \
# 664659         1108337           854    55              59.940
# 716127         1166447          9210   277              84.982
# 192609          192609          1480    32              59.958
# 161165          161165          6007    64              69.030
# 7219              7219         12110   223             122.275
# ...                ...           ...   ...                 ...
# 200211          200211          8881    44              59.790
# 137031          137031          8031   119              59.980
# 666892         1110717         10029    46             101.860
# 114369          114369          1760   176              84.940
# 473253          473253          1094   141             113.830
#
#         year_of_completion  transaction_year_month  transaction_date  floor  \
# 664659                1989                  201703                 4      4
# 716127                2013                  201710                 3     10
# 192609                2000                  201011                 3      1
# 161165                1987                  201308                 4     11
# 7219                  1993                  201201                 2      3
# ...                    ...                     ...               ...    ...
# 200211                2004                  201205                 2      6
# 137031                2004                  201104                 3      8
# 666892                1995                  201711                 3      5
# 114369                2010                  201302                 1      7
# 473253                2004                  200903                 2     11
#
#         transaction_real_price  hangang  ...  number_of_subway_stations  \
# 664659                   24800        0  ...                          8
# 716127                   93800        0  ...                         12
# 192609                   23900        0  ...                         13
# 161165                   23950        0  ...                          3
# 7219                     42000        0  ...                         23
# ...                        ...      ...  ...                        ...
# 200211                   26800        0  ...                         13
# 137031                   27000        0  ...                          3
# 666892                   48000        0  ...                          8
# 114369                   48500        0  ...                          9
# 473253                   55000        0  ...                          4
#
#         department_stores  day_diff  year  month  age  is_rebuild  \
# 664659                  0        10  2017      3   28           0
# 716127                  0         9  2017     10    4           0
# 192609                  1         9  2010     11   10           0
# 161165                  0        10  2013      8   26           0
# 7219                    0         9  2012      1   19           0
# ...                   ...       ...   ...    ...  ...         ...
# 200211                  0         9  2012      5    8           0
# 137031                  1         9  2011      4    7           0
# 666892                  0         9  2017     11   22           0
# 114369                  1         7  2013      2    3           0
# 473253                  1         9  2009      3    5           0
#
#         special_high_school  middle_school  elementary_schools
# 664659                    0             29                  45
# 716127                    0             32                  43
# 192609                    0             39                  65
# 161165                    1             39                  65
# 7219                      1             25                  39
# ...                     ...            ...                 ...
# 200211                    0             39                  65
# 137031                    0             30                  43
# 666892                    0             29                  45
# 114369                    1             30                  43
# 473253                    1             32                  43
#
# [556713 rows x 24 columns]

# %%
#상관관계 확인
k=train_set.shape[1] #히트맵 변수 갯수
corrmat = train_set.corr() #변수간의 상관관계
cols = corrmat.nlargest(k, 'transaction_real_price')['transaction_real_price'].index #price기준으로 제일 큰순서대로 20개를 뽑아냄
cm = np.corrcoef(train_set[cols].values.T)
f, ax = plt.subplots(figsize=(8, 6))
sns.heatmap(data = cm, annot=True, square=True, fmt = '.2f', linewidths=.5, cmap='Reds', 
            yticklabels = cols.values, xticklabels = cols.values)
# Out:
# <Axes: >

# %%
#train_set=train_set.drop(labels=['special_high_school','middle_school','elementary_schools'],axis=1)\
#test_set=test_set.drop(labels=['special_high_school','middle_school','elementary_schools'],axis=1)

# %%
train_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 556713 entries, 664659 to 473253
# Data columns (total 24 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   transaction_id             556713 non-null  int64
#  1   apartment_id               556713 non-null  int64
#  2   dong                       556713 non-null  int64
#  3   exclusive_use_area         556713 non-null  float64
#  4   year_of_completion         556713 non-null  int64
#  5   transaction_year_month     556713 non-null  int64
#  6   transaction_date           556713 non-null  int64
#  7   floor                      556713 non-null  int64
#  8   transaction_real_price     556713 non-null  int64
#  9   hangang                    556713 non-null  int64
#  10  CBD                        556713 non-null  int64
#  11  park                       556713 non-null  int64
#  12  price/area                 556713 non-null  float64
#  13  base_money_rate            556713 non-null  float64
#  14  number_of_subway_stations  556713 non-null  int64
#  15  department_stores          556713 non-null  int64
#  16  day_diff                   556713 non-null  int64
#  17  year                       556713 non-null  int64
#  18  month                      556713 non-null  int64
#  19  age                        556713 non-null  int64
#  20  is_rebuild                 556713 non-null  int64
#  21  special_high_school        556713 non-null  int64
#  22  middle_school              556713 non-null  int64
#  23  elementary_schools         556713 non-null  int64
# dtypes: float64(3), int64(21)
# memory usage: 106.2 MB

# %%
import missingno as msno
msno.matrix(train_set,figsize=(6,3))
# Out:
# <Axes: >

# %%
train_set.head(40)
# Out:
#         transaction_id  apartment_id  dong  exclusive_use_area  \
# 664659         1108337           854    55             59.9400
# 716127         1166447          9210   277             84.9820
# 192609          192609          1480    32             59.9580
# 161165          161165          6007    64             69.0300
# 7219              7219         12110   223            122.2750
# 434788          434788          7968   146             59.9000
# 241501          241501          9167   152             59.1700
# 433119          433119         10024   154             59.4000
# 51470            51470          1318   242             84.9100
# 670555         1114633         10103   128             84.9800
# 696438         1143831          7474    38             84.5600
# 128811          128811          9611    77             59.9800
# 493483          493483          4739   301            122.8250
# 333628          333628          3523   215             84.9550
# 360669          360669          9345    80             84.9500
# 400823          400823         12015    95             59.9400
# 89362            89362          7219    97            102.7000
# 360432          360432          9810   125             58.1400
# 632736          632736         11526   114             37.1000
# 180068          180068          4591    44             33.2800
# 457508          457508         11298   266            114.4400
# 376178          376178          2630    83            114.9500
# 472415          472415          7343    81             59.9500
# 531910          531910           851   320             84.9400
# 58219            58219           891   248             84.9500
# 56151            56151          9420   248             84.9700
# 649794          649794           993   241            145.0000
# 100205          100205          3261    46             84.9800
# 199007          199007          5961    32             31.9500
# 678855         1123957          5955    32             41.3000
# 466401          466401          7283   169             59.6700
# 665818         1109525           827   107             84.6475
# 235512          235512         10673    51             49.6000
# 671325         1115865          8031   119             59.9800
# 540462          540462          9094   321             76.7900
# 730207         1183420         10069   300             81.8800
# 506589          506589          4716   324             59.9800
# 414752          414752           753    47             61.6500
# 451795          451795           866   204             42.6300
# 330131          330131          4406   278            115.4700
#
#         year_of_completion  transaction_year_month  transaction_date  floor  \
# 664659                1989                  201703                 4      4
# 716127                2013                  201710                 3     10
# 192609                2000                  201011                 3      1
# 161165                1987                  201308                 4     11
# 7219                  1993                  201201                 2      3
# 434788                1998                  201405                 2     10
# 241501                2005                  200803                 3      4
# 433119                1997                  201312                 2     23
# 51470                 1996                  201212                 4      3
# 670555                2006                  201709                 2      4
# 696438                1986                  201706                 5      3
# 128811                2004                  201512                 4      8
# 493483                2004                  200810                 4     10
# 333628                2005                  201606                 5      4
# 360669                2004                  201501                 3      1
# 400823                2001                  201508                 3      6
# 89362                 1995                  201304                 2      3
# 360432                1995                  201501                 3     15
# 632736                1991                  201306                 2      8
# 180068                1986                  200804                 5      3
# 457508                1988                  201309                 2      8
# 376178                1999                  200802                 3      1
# 472415                2005                  200805                 2     21
# 531910                2005                  200907                 2     13
# 58219                 1999                  201608                 2     19
# 56151                 1999                  201508                 4      2
# 649794                2011                  201610                 3      1
# 100205                1993                  201608                 4     11
# 199007                1988                  201201                 3      4
# 678855                1987                  201704                 3     11
# 466401                2001                  201512                 4     17
# 665818                2006                  201707                 2      4
# 235512                1999                  201607                 2      6
# 671325                2004                  201702                 2      3
# 540462                1979                  201108                 4     14
# 730207                1980                  201702                 3      6
# 506589                2009                  201212                 2     12
# 414752                2003                  201409                 3      1
# 451795                1998                  201009                 3      8
# 330131                1986                  201510                 2     11
#
#         transaction_real_price  hangang  ...  number_of_subway_stations  \
# 664659                   24800        0  ...                          8
# 716127                   93800        0  ...                         12
# 192609                   23900        0  ...                         13
# 161165                   23950        0  ...                          3
# 7219                     42000        0  ...                         23
# 434788                   28000        0  ...                         11
# 241501                   19500        0  ...                         13
# 433119                   30000        0  ...                         11
# 51470                    44500        1  ...                         11
# 670555                   41500        0  ...                          9
# 696438                   33900        0  ...                          5
# 128811                   32000        0  ...                          9
# 493483                   95000        0  ...                         12
# 333628                   47000        0  ...                          5
# 360669                   34000        0  ...                          9
# 400823                   35000        0  ...                          7
# 89362                    42000        0  ...                          8
# 360432                   29000        0  ...                          9
# 632736                   17250        0  ...                         14
# 180068                   24900        0  ...                         13
# 457508                   64900        0  ...                         12
# 376178                   40500        0  ...                          7
# 472415                   38000        0  ...                          4
# 531910                   67000        0  ...                         21
# 58219                    51500        1  ...                         11
# 56151                    53000        1  ...                         11
# 649794                   95000        0  ...                         14
# 100205                   36000        0  ...                          8
# 199007                   19400        0  ...                         13
# 678855                   27100        0  ...                         13
# 466401                   37000        0  ...                         12
# 665818                   46900        0  ...                          8
# 235512                   22000        0  ...                         13
# 671325                   34350        0  ...                          3
# 540462                   90000        0  ...                         21
# 730207                  102500        0  ...                         28
# 506589                   80000        1  ...                         12
# 414752                   18000        0  ...                          1
# 451795                   24750        0  ...                         12
# 330131                  118500        0  ...                          5
#
#         department_stores  day_diff  year  month  age  is_rebuild  \
# 664659                  0        10  2017      3   28           0
# 716127                  0         9  2017     10    4           0
# 192609                  1         9  2010     11   10           0
# 161165                  0        10  2013      8   26           0
# 7219                    0         9  2012      1   19           0
# 434788                  0         9  2014      5   16           0
# 241501                  0         9  2008      3    3           0
# 433119                  0         9  2013     12   16           0
# 51470                   0        10  2012     12   16           0
# 670555                  0         9  2017      9   11           0
# 696438                  0         9  2017      6   31           1
# 128811                  0        10  2015     12   11           0
# 493483                  0        10  2008     10    4           0
# 333628                  0         9  2016      6   11           0
# 360669                  0         9  2015      1   11           0
# 400823                  0         9  2015      8   14           0
# 89362                   0         9  2013      4   18           0
# 360432                  0         9  2015      1   20           0
# 632736                  1         9  2013      6   22           0
# 180068                  0         9  2008      4   22           0
# 457508                  0         9  2013      9   25           0
# 376178                  0         9  2008      2    9           0
# 472415                  0         9  2008      5    3           0
# 531910                  0         9  2009      7    4           0
# 58219                   1         9  2016      8   17           0
# 56151                   1        10  2015      8   16           0
# 649794                  0         9  2016     10    5           0
# 100205                  0        10  2016      8   23           0
# 199007                  1         9  2012      1   24           0
# 678855                  1         9  2017      4   30           1
# 466401                  0        10  2015     12   14           0
# 665818                  0         9  2017      7   11           0
# 235512                  0         9  2016      7   17           0
# 671325                  1         9  2017      2   13           0
# 540462                  1        10  2011      8   32           1
# 730207                  0         9  2017      2   37           1
# 506589                  1         9  2012     12    3           0
# 414752                  0         9  2014      9   11           0
# 451795                  0         9  2010      9   12           0
# 330131                  1         9  2015     10   29           0
#
#         special_high_school  middle_school  elementary_schools
# 664659                    0             29                  45
# 716127                    0             32                  43
# 192609                    0             39                  65
# 161165                    1             39                  65
# 7219                      1             25                  39
# 434788                    0             35                  68
# 241501                    0             46                  71
# 433119                    0             35                  68
# 51470                     2             23                  43
# 670555                    1             30                  43
# 696438                    0             41                  65
# 128811                    1             30                  43
# 493483                    0             40                  56
# 333628                    0             41                  65
# 360669                    2             41                  65
# 400823                    1             35                  68
# 89362                     0             29                  45
# 360432                    2             41                  65
# 632736                    0             48                  70
# 180068                    0             39                  65
# 457508                    0             32                  43
# 376178                    1             35                  68
# 472415                    1             32                  43
# 531910                    1             40                  56
# 58219                     2             23                  43
# 56151                     2             23                  43
# 649794                    0             48                  70
# 100205                    0             29                  45
# 199007                    0             39                  65
# 678855                    0             39                  65
# 466401                    0             32                  43
# 665818                    0             29                  45
# 235512                    0             39                  65
# 671325                    0             30                  43
# 540462                    1             40                  56
# 730207                    0             48                  70
# 506589                    0             40                  56
# 414752                    0             35                  68
# 451795                    0             32                  43
# 330131                    0             41                  65
#
# [40 rows x 24 columns]

# %%
train_set.columns
# Out:
# Index(['transaction_id', 'apartment_id', 'dong', 'exclusive_use_area',
#        'year_of_completion', 'transaction_year_month', 'transaction_date',
#        'floor', 'transaction_real_price', 'hangang', 'CBD', 'park',
#        'price/area', 'base_money_rate', 'number_of_subway_stations',
#        'department_stores', 'day_diff', 'year', 'month', 'age', 'is_rebuild',
#        'special_high_school', 'middle_school', 'elementary_schools'],
#       dtype='object')

# %%
test_set.head(40)
# Out:
#         transaction_id  apartment_id  dong  exclusive_use_area  \
# 220910          220910          5038    32             44.3300
# 321435          321435          4398   215             59.2900
# 406875          406875          4956    83             84.8960
# 143328          143328          3619   119             59.9900
# 634387          634387          6467   226             59.6400
# 460637          460637          5025   211             84.9500
# 295315          295315          6033   261             84.9800
# 78225            78225         10222   126             19.5250
# 639547          639547           684   161             59.8700
# 57684            57684          1472   269             75.5500
# 42189            42189          4945   186             59.9000
# 86748            86748         11501    61             35.3000
# 336811          336811          9810   125             37.6700
# 309772          309772         12116   215             84.8400
# 60738            60738          9809   101             59.7900
# 434940          434940          2259   199             84.9800
# 189260          189260          5959    32             58.0100
# 177424          177424          5945    32             58.0100
# 286520          286520          4203   274             84.2000
# 625143          625143          6467   226             83.1800
# 95956            95956          6149    46             84.4000
# 29905            29905          2379   201             84.4200
# 64808            64808          9509   134             58.4200
# 276328          276328         12374    96             84.7800
# 482838          482838          8714   141             84.9600
# 715549         1165846          7283   169             59.6700
# 548235          548235         12069   320             32.6500
# 293655          293655          6029   261             84.7600
# 477648          477648          1116   141             84.7500
# 523272          523272          6363   281            101.0482
# 358902          358902          3278    65             84.9500
# 535106          535106          7164   288             40.5300
# 326228          326228          4009   278             84.9400
# 181000          181000          5389    44             49.5000
# 486034          486034          1945   174             84.9900
# 178812          178812         11172    82             75.3500
# 84071            84071          6898    61             71.5910
# 319001          319001          9265   215             84.5100
# 270405          270405         10169   113             56.0200
# 611752          611752          8497   294             83.0600
#
#         year_of_completion  transaction_year_month  transaction_date  floor  \
# 220910                1988                  201503                 2     12
# 321435                1988                  201401                 2      4
# 406875                2010                  201609                 5      1
# 143328                2011                  201509                 3      3
# 634387                2000                  201312                 4      9
# 460637                1998                  201408                 4     19
# 295315                2010                  201501                 3     14
# 78225                 2012                  201606                 2     10
# 639547                2009                  201501                 3      4
# 57684                 1989                  201606                 3      1
# 42189                 2001                  201603                 2     20
# 86748                 1988                  201107                 4      5
# 336811                1995                  200801                 2     11
# 309772                1995                  200908                 4      2
# 60738                 2001                  200806                 2     24
# 434940                2004                  201406                 3     11
# 189260                1988                  200912                 3      5
# 177424                1988                  200802                 2     13
# 286520                2003                  201101                 2      2
# 625143                2000                  201012                 3      2
# 95956                 1998                  201505                 3      2
# 29905                 2001                  201106                 3     16
# 64808                 2003                  201103                 2      3
# 276328                1997                  201509                 2      9
# 482838                2000                  201405                 2     16
# 715549                2001                  201708                 2     15
# 548235                1999                  201311                 3     22
# 293655                2006                  201407                 2      4
# 477648                2004                  201107                 3     13
# 523272                2013                  201608                 2     23
# 358902                1993                  201409                 3      1
# 535106                1984                  201004                 5      2
# 326228                2005                  201503                 2     11
# 181000                1995                  200805                 4      9
# 486034                2005                  201504                 2      3
# 178812                1997                  200803                 4      9
# 84071                 2001                  200909                 5      9
# 319001                2011                  201304                 5      8
# 270405                2006                  201306                 3     14
# 611752                1988                  201609                 5     16
#
#         transaction_real_price  hangang  ...  number_of_subway_stations  \
# 220910                   15000        0  ...                         13
# 321435                   36500        0  ...                          5
# 406875                   38000        0  ...                          7
# 143328                   36000        0  ...                          3
# 634387                   34300        1  ...                         14
# 460637                   39000        0  ...                         12
# 295315                   55700        1  ...                         16
# 78225                    13200        0  ...                          6
# 639547                   38500        0  ...                         14
# 57684                    55000        1  ...                         11
# 42189                    37500        0  ...                         14
# 86748                    13000        0  ...                          8
# 336811                   18200        0  ...                          9
# 309772                   42800        0  ...                          5
# 60738                    30000        0  ...                          6
# 434940                   51500        0  ...                         11
# 189260                   29000        0  ...                         13
# 177424                   24000        0  ...                         13
# 286520                   56000        1  ...                         16
# 625143                   43950        1  ...                         14
# 95956                    29000        0  ...                          8
# 29905                    60000        1  ...                         14
# 64808                    32500        0  ...                          6
# 276328                   39000        0  ...                          5
# 482838                   40000        0  ...                          4
# 715549                   46500        0  ...                         12
# 548235                   23500        0  ...                         21
# 293655                   64000        1  ...                         16
# 477648                   47000        0  ...                          4
# 523272                   85000        0  ...                         12
# 358902                   31000        0  ...                          9
# 535106                   67500        0  ...                         21
# 326228                   57500        0  ...                          5
# 181000                   22800        0  ...                         13
# 486034                   46000        0  ...                          4
# 178812                   38500        0  ...                         13
# 84071                    27000        0  ...                          8
# 319001                   39000        0  ...                          5
# 270405                   32500        0  ...                          5
# 611752                   95000        0  ...                         28
#
#         department_stores  day_diff  year  month  age  is_rebuild  \
# 220910                  1         9  2015      3   27           0
# 321435                  0         9  2014      1   26           0
# 406875                  0         9  2016      9    6           0
# 143328                  1         9  2015      9    4           0
# 634387                  0        10  2013     12   13           0
# 460637                  0        10  2014      8   16           0
# 295315                  0         9  2015      1    5           0
# 78225                   0         9  2016      6    4           0
# 639547                  0         9  2015      1    6           0
# 57684                   0         9  2016      6   27           0
# 42189                   0         9  2016      3   15           0
# 86748                   0        10  2011      7   23           0
# 336811                  0         9  2008      1   13           0
# 309772                  0        10  2009      8   14           0
# 60738                   0         9  2008      6    7           0
# 434940                  0         9  2014      6   10           0
# 189260                  1         9  2009     12   21           0
# 177424                  1         9  2008      2   20           0
# 286520                  0         9  2011      1    8           0
# 625143                  0         9  2010     12   10           0
# 95956                   0         9  2015      5   17           0
# 29905                   0         9  2011      6   10           0
# 64808                   0         9  2011      3    8           0
# 276328                  0         9  2015      9   18           0
# 482838                  1         9  2014      5   14           0
# 715549                  0         9  2017      8   16           0
# 548235                  0         9  2013     11   14           0
# 293655                  0         9  2014      7    8           0
# 477648                  1         9  2011      7    7           0
# 523272                  0         9  2016      8    3           0
# 358902                  1         9  2014      9   21           0
# 535106                  0         9  2010      4   26           0
# 326228                  1         9  2015      3   10           0
# 181000                  0        10  2008      5   13           0
# 486034                  0         9  2015      4   10           0
# 178812                  0        10  2008      3   11           0
# 84071                   0         9  2009      9    8           0
# 319001                  0         9  2013      4    2           0
# 270405                  0         9  2013      6    7           0
# 611752                  0         9  2016      9   28           0
#
#         special_high_school  middle_school  elementary_schools
# 220910                    0             39                  65
# 321435                    0             41                  65
# 406875                    1             35                  68
# 143328                    0             30                  43
# 634387                    0             48                  70
# 460637                    0             32                  43
# 295315                    0             46                  71
# 78225                     0             29                  45
# 639547                    0             48                  70
# 57684                     2             23                  43
# 42189                     0             23                  43
# 86748                     0             29                  45
# 336811                    2             41                  65
# 309772                    0             41                  65
# 60738                     0             29                  45
# 434940                    0             35                  68
# 189260                    0             39                  65
# 177424                    0             39                  65
# 286520                    0             46                  71
# 625143                    0             48                  70
# 95956                     0             29                  45
# 29905                     0             23                  43
# 64808                     0             29                  45
# 276328                    0             46                  71
# 482838                    1             32                  43
# 715549                    0             32                  43
# 548235                    1             40                  56
# 293655                    0             46                  71
# 477648                    1             32                  43
# 523272                    0             40                  56
# 358902                    2             41                  65
# 535106                    1             40                  56
# 326228                    0             41                  65
# 181000                    0             39                  65
# 486034                    1             32                  43
# 178812                    0             39                  65
# 84071                     0             29                  45
# 319001                    0             41                  65
# 270405                    0             46                  71
# 611752                    0             48                  70
#
# [40 rows x 24 columns]

# %%
train_columns = []
for column in train_set.columns[:]:
    if train_set[column].skew() >= 1:
        print("%s -> Skewness: %f, Kurtosis: %f" %  (column,train_set[column].skew(), 
                                                 train_set[column].kurt()))
        train_columns.append(column)
    elif train_set[column].kurt() >= 3:
        print("%s -> Skewness: %f, Kurtosis: %f" %  (column,train_set[column].skew(), 
                                                 train_set[column].kurt()))
        train_columns.append(column)
# Out:
# transaction_id -> Skewness: 1.069116, Kurtosis: 0.460242
# exclusive_use_area -> Skewness: 1.263251, Kurtosis: 3.750259
# floor -> Skewness: 1.099613, Kurtosis: 2.415969
# transaction_real_price -> Skewness: 3.387024, Kurtosis: 23.486711
# hangang -> Skewness: 2.254406, Kurtosis: 3.082355
# CBD -> Skewness: 1.167436, Kurtosis: -0.637095
# price/area -> Skewness: 2.007684, Kurtosis: 5.696937
# base_money_rate -> Skewness: 1.543407, Kurtosis: 2.146340
# department_stores -> Skewness: 1.872658, Kurtosis: 2.357890
# day_diff -> Skewness: -0.600418, Kurtosis: 4.514374
# is_rebuild -> Skewness: 3.181670, Kurtosis: 8.123054
# special_high_school -> Skewness: 1.224228, Kurtosis: 0.336852

# %%
train_columns
# Out:
# ['transaction_id',
#  'exclusive_use_area',
#  'floor',
#  'transaction_real_price',
#  'hangang',
#  'CBD',
#  'price/area',
#  'base_money_rate',
#  'department_stores',
#  'day_diff',
#  'is_rebuild',
#  'special_high_school']

# %%
for column in train_columns :
    train_set[column] = np.log1p(train_set[column])
    test_set[column] = np.log1p(test_set[column])
    print("%s -> Skewness: %f, Kurtosis: %f" %  (column,train_set[column].skew(), 
                                                 train_set[column].kurt()))
# Out:
# transaction_id -> Skewness: -1.597564, Kurtosis: 4.575699
# exclusive_use_area -> Skewness: -0.590381, Kurtosis: 2.305678
# floor -> Skewness: -0.402609, Kurtosis: -0.531463
# transaction_real_price -> Skewness: 0.356755, Kurtosis: 0.587102
# hangang -> Skewness: 2.254406, Kurtosis: 3.082355
# CBD -> Skewness: 1.167436, Kurtosis: -0.637095
# price/area -> Skewness: 0.631737, Kurtosis: 0.747074
# base_money_rate -> Skewness: 0.846287, Kurtosis: 0.232532
# department_stores -> Skewness: 1.705804, Kurtosis: 1.127075
# day_diff -> Skewness: -1.135047, Kurtosis: 6.704011
# is_rebuild -> Skewness: 3.181670, Kurtosis: 8.123054
# special_high_school -> Skewness: 0.902770, Kurtosis: -0.793871

# %%
#상관관계 확인
k=train_set.shape[1] #히트맵 변수 갯수
corrmat = train_set.corr() #변수간의 상관관계
cols = corrmat.nlargest(k, 'transaction_real_price')['transaction_real_price'].index #price기준으로 제일 큰순서대로 20개를 뽑아냄
cm = np.corrcoef(train_set[cols].values.T)
f, ax = plt.subplots(figsize=(30, 8))
sns.heatmap(data = cm, annot=True, square=True, fmt = '.2f', linewidths=.5, cmap='Reds', 
            yticklabels = cols.values, xticklabels = cols.values)
# Out:
# <Axes: >

# %%
train_set
# Out:
#         transaction_id  apartment_id  dong  exclusive_use_area  \
# 664659       13.918372           854    55            4.109890
# 716127       13.969474          9210   277            4.454138
# 192609       12.168423          1480    32            4.110185
# 161165       11.990190          6007    64            4.248924
# 7219          8.884610         12110   223            4.814418
# ...                ...           ...   ...                 ...
# 200211       12.207132          8881    44            4.107425
# 137031       11.827970          8031   119            4.110546
# 666892       13.920517         10029    46            4.633369
# 114369       11.647194          1760   176            4.453649
# 473253       13.067388          1094   141            4.743453
#
#         year_of_completion  transaction_year_month  transaction_date  \
# 664659                1989                  201703                 4
# 716127                2013                  201710                 3
# 192609                2000                  201011                 3
# 161165                1987                  201308                 4
# 7219                  1993                  201201                 2
# ...                    ...                     ...               ...
# 200211                2004                  201205                 2
# 137031                2004                  201104                 3
# 666892                1995                  201711                 3
# 114369                2010                  201302                 1
# 473253                2004                  200903                 2
#
#            floor  transaction_real_price  hangang  ...  \
# 664659  1.609438               10.118639      0.0  ...
# 716127  2.397895               11.448931      0.0  ...
# 192609  0.693147               10.081676      0.0  ...
# 161165  2.484907               10.083765      0.0  ...
# 7219    1.386294               10.645449      0.0  ...
# ...          ...                     ...      ...  ...
# 200211  1.945910               10.196194      0.0  ...
# 137031  2.197225               10.203629      0.0  ...
# 666892  1.791759               10.778977      0.0  ...
# 114369  2.079442               10.789340      0.0  ...
# 473253  2.484907               10.915107      0.0  ...
#
#         number_of_subway_stations  department_stores  day_diff  year  month  \
# 664659                          8           0.000000  2.397895  2017      3
# 716127                         12           0.000000  2.302585  2017     10
# 192609                         13           0.693147  2.302585  2010     11
# 161165                          3           0.000000  2.397895  2013      8
# 7219                           23           0.000000  2.302585  2012      1
# ...                           ...                ...       ...   ...    ...
# 200211                         13           0.000000  2.302585  2012      5
# 137031                          3           0.693147  2.302585  2011      4
# 666892                          8           0.000000  2.302585  2017     11
# 114369                          9           0.693147  2.079442  2013      2
# 473253                          4           0.693147  2.302585  2009      3
#
#         age  is_rebuild  special_high_school  middle_school  \
# 664659   28         0.0             0.000000             29
# 716127    4         0.0             0.000000             32
# 192609   10         0.0             0.000000             39
# 161165   26         0.0             0.693147             39
# 7219     19         0.0             0.693147             25
# ...     ...         ...                  ...            ...
# 200211    8         0.0             0.000000             39
# 137031    7         0.0             0.000000             30
# 666892   22         0.0             0.000000             29
# 114369    3         0.0             0.693147             30
# 473253    5         0.0             0.693147             32
#
#         elementary_schools
# 664659                  45
# 716127                  43
# 192609                  65
# 161165                  65
# 7219                    39
# ...                    ...
# 200211                  65
# 137031                  43
# 666892                  45
# 114369                  43
# 473253                  43
#
# [556713 rows x 24 columns]

# %% [markdown]
# ### RMSE 부분 에러가능성 있습니다
# ### 변수는 LBGM 실습 코드 기준 작성되었습니다.
# -호윤

# %%
# !pip install optuna
# Out:
# Collecting optuna
#   Downloading optuna-2.10.0-py3-none-any.whl (308 kB)
#      |████████████████████████████████| 308 kB 5.3 MB/s
# Collecting alembic
#   Downloading alembic-1.7.7-py3-none-any.whl (210 kB)
#      |████████████████████████████████| 210 kB 46.4 MB/s
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.8.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.36)
# Collecting colorlog
#   Downloading colorlog-6.6.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Collecting cliff
#   Downloading cliff-3.10.1-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 3.9 MB/s
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.8)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.7.1)
# Collecting Mako
#   Downloading Mako-1.2.0-py3-none-any.whl (78 kB)
#      |████████████████████████████████| 78 kB 6.0 MB/s
# Collecting stevedore>=2.0.1
#   Downloading stevedore-3.5.0-py3-none-any.whl (49 kB)
#      |████████████████████████████████| 49 kB 5.5 MB/s
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.9.0-py2.py3-none-any.whl (112 kB)
#      |████████████████████████████████| 112 kB 44.1 MB/s
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.0-py3-none-any.whl (29 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 52.0 MB/s
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.2.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)
# Building wheels for collected packages: pyperclip
#   Building wheel for pyperclip (setup.py) ... done
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11137 sha256=c4cb67b2f5c4846a0966d3e203fb3fb4356e42773cf5881c8e64e18b1fbaa212
#   Stored in directory: /root/.cache/pip/wheels/9f/18/84/8f69f8b08169c7bae2dde6bd7daf0c19fca8c8e500ee620a28
# Successfully built pyperclip
# Installing collected packages: pyperclip, pbr, stevedore, Mako, cmd2, autopage, colorlog, cmaes, cliff, alembic, optuna
# Successfully installed Mako-1.2.0 alembic-1.7.7 autopage-0.5.0 cliff-3.10.1 cmaes-0.8.2 cmd2-2.4.1 colorlog-6.6.0 optuna-2.10.0 pbr-5.9.0 pyperclip-1.8.2 stevedore-3.5.0

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
from sklearn.linear_model import LinearRegression, ElasticNet, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import  LabelEncoder
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import xgboost as xgb
import lightgbm as lgb
import re
import optuna
from optuna.integration import XGBoostPruningCallback
sns.set_theme(style="darkgrid")
# %matplotlib inline

# %%
train_X, train_y = train_set.drop('transaction_real_price', axis=1), train_set['transaction_real_price']
print(train_X.shape, train_y.shape)
# Out:
# (556713, 23) (556713,)

# %%
def RMSE(y, y_pred):
    rmse = mean_squared_error(y, y_pred) ** 0.5
    return rmse

def rmse_cv(model):
    # cv별로 학습하는 함수
    tscv = TimeSeriesSplit(n_splits=10)
    rmse_list = []
    model_name = model.__class__.__name__
    for _, (train_index, test_index) in tqdm(enumerate(tscv.split(train_X), start=1), desc=f'{model_name} Cross Validations...', total=10):
        X_train, X_test = train_X.iloc[train_index], train_X.iloc[test_index]
        y_train, y_test = train_y.iloc[train_index], train_y.iloc[test_index]
        clf = model.fit(X_train, y_train)
        pred = clf.predict(X_test)
        rmse = RMSE(y_test, pred) 
        rmse_list.append(rmse)
    return model_name, rmse_list

def print_rmse_score(model):
    # cv별 프린팅, 평균 저장
    model_name, score = rmse_cv(model)
    for i, r in enumerate(score, start=1):
        print(f'{i} FOLDS: {model_name} RMSE: {r:.4f}')
    print(f'\n{model_name} mean RMSE: {np.mean(score):.4f}')
    print('='*40)
    return model_name, np.mean(score)

# %%
reg = LinearRegression(n_jobs=-1)
ridge = Ridge(alpha=0.8, random_state=1)
lasso = Lasso(alpha = 0.01, random_state=1)
Enet = ElasticNet(alpha=0.03, l1_ratio=0.01, random_state=1)
DTree = DecisionTreeRegressor(max_depth=6, min_samples_split=10, min_samples_leaf=15, random_state=1)
rf = RandomForestRegressor(n_estimators=500, criterion='squared_error', max_depth=9, min_samples_split=50,
                           min_samples_leaf=5, random_state=1, n_jobs=-1)
model_xgb = xgb.XGBRegressor(n_estimators=500, max_depth=9, min_child_weight=5, gamma=0.1, n_jobs=-1)
model_lgb = lgb.LGBMRegressor(n_estimators=500, max_depth=9, min_child_weight=5, n_jobs=-1)

# %%
models = []
scores = []
for model in [reg, ridge, lasso, Enet, DTree, rf, model_xgb, model_lgb]:
    model_name, mean_score = print_rmse_score(model)
    models.append(model_name)
    scores.append(mean_score)
# Out:
# LinearRegression Cross Validations...: 100%|██████████| 10/10 [00:02<00:00,  4.87it/s]
# 1 FOLDS: LinearRegression RMSE: 0.0209
# 2 FOLDS: LinearRegression RMSE: 0.0155
# 3 FOLDS: LinearRegression RMSE: 0.0157
# 4 FOLDS: LinearRegression RMSE: 0.0188
# 5 FOLDS: LinearRegression RMSE: 0.0179
# 6 FOLDS: LinearRegression RMSE: 0.0212
# 7 FOLDS: LinearRegression RMSE: 0.0171
# 8 FOLDS: LinearRegression RMSE: 0.0171
# 9 FOLDS: LinearRegression RMSE: 0.0172
# 10 FOLDS: LinearRegression RMSE: 0.0165
#
# LinearRegression mean RMSE: 0.0178
# ========================================
# Ridge Cross Validations...: 100%|██████████| 10/10 [00:00<00:00, 13.89it/s]
# 1 FOLDS: Ridge RMSE: 0.0209
# 2 FOLDS: Ridge RMSE: 0.0155
# 3 FOLDS: Ridge RMSE: 0.0157
# 4 FOLDS: Ridge RMSE: 0.0188
# 5 FOLDS: Ridge RMSE: 0.0179
# 6 FOLDS: Ridge RMSE: 0.0212
# 7 FOLDS: Ridge RMSE: 0.0171
# 8 FOLDS: Ridge RMSE: 0.0171
# 9 FOLDS: Ridge RMSE: 0.0172
# 10 FOLDS: Ridge RMSE: 0.0165
#
# Ridge mean RMSE: 0.0178
# ========================================
# Lasso Cross Validations...: 100%|██████████| 10/10 [00:04<00:00,  2.14it/s]
# 1 FOLDS: Lasso RMSE: 0.0598
# 2 FOLDS: Lasso RMSE: 0.0582
# 3 FOLDS: Lasso RMSE: 0.0579
# 4 FOLDS: Lasso RMSE: 0.0590
# 5 FOLDS: Lasso RMSE: 0.0591
# 6 FOLDS: Lasso RMSE: 0.0593
# 7 FOLDS: Lasso RMSE: 0.0591
# 8 FOLDS: Lasso RMSE: 0.0580
# 9 FOLDS: Lasso RMSE: 0.0588
# 10 FOLDS: Lasso RMSE: 0.0588
#
# Lasso mean RMSE: 0.0588
# ========================================
# ElasticNet Cross Validations...: 100%|██████████| 10/10 [01:49<00:00, 10.99s/it]
# 1 FOLDS: ElasticNet RMSE: 0.1161
# 2 FOLDS: ElasticNet RMSE: 0.1155
# 3 FOLDS: ElasticNet RMSE: 0.1149
# 4 FOLDS: ElasticNet RMSE: 0.1159
# 5 FOLDS: ElasticNet RMSE: 0.1162
# 6 FOLDS: ElasticNet RMSE: 0.1151
# 7 FOLDS: ElasticNet RMSE: 0.1168
# 8 FOLDS: ElasticNet RMSE: 0.1147
# 9 FOLDS: ElasticNet RMSE: 0.1166
# 10 FOLDS: ElasticNet RMSE: 0.1163
#
# ElasticNet mean RMSE: 0.1158
# ========================================
# DecisionTreeRegressor Cross Validations...: 100%|██████████| 10/10 [00:11<00:00,  1.11s/it]
# 1 FOLDS: DecisionTreeRegressor RMSE: 0.1148
# 2 FOLDS: DecisionTreeRegressor RMSE: 0.1125
# 3 FOLDS: DecisionTreeRegressor RMSE: 0.1139
# 4 FOLDS: DecisionTreeRegressor RMSE: 0.1206
# 5 FOLDS: DecisionTreeRegressor RMSE: 0.1116
# 6 FOLDS: DecisionTreeRegressor RMSE: 0.1100
# 7 FOLDS: DecisionTreeRegressor RMSE: 0.1121
# 8 FOLDS: DecisionTreeRegressor RMSE: 0.1120
# 9 FOLDS: DecisionTreeRegressor RMSE: 0.1117
# 10 FOLDS: DecisionTreeRegressor RMSE: 0.1098
#
# DecisionTreeRegressor mean RMSE: 0.1129
# ========================================
# RandomForestRegressor Cross Validations...: 100%|██████████| 10/10 [12:27<00:00, 74.74s/it]
# 1 FOLDS: RandomForestRegressor RMSE: 0.0420
# 2 FOLDS: RandomForestRegressor RMSE: 0.0345
# 3 FOLDS: RandomForestRegressor RMSE: 0.0350
# 4 FOLDS: RandomForestRegressor RMSE: 0.0387
# 5 FOLDS: RandomForestRegressor RMSE: 0.0325
# 6 FOLDS: RandomForestRegressor RMSE: 0.0326
# 7 FOLDS: RandomForestRegressor RMSE: 0.0342
# 8 FOLDS: RandomForestRegressor RMSE: 0.0316
# 9 FOLDS: RandomForestRegressor RMSE: 0.0319
# 10 FOLDS: RandomForestRegressor RMSE: 0.0320
#
# RandomForestRegressor mean RMSE: 0.0345
# ========================================
# XGBRegressor Cross Validations...: 100%|██████████| 10/10 [00:07<00:00,  1.26it/s]
# 1 FOLDS: XGBRegressor RMSE: 0.0372
# 2 FOLDS: XGBRegressor RMSE: 0.0331
# 3 FOLDS: XGBRegressor RMSE: 0.0355
# 4 FOLDS: XGBRegressor RMSE: 0.0379
# 5 FOLDS: XGBRegressor RMSE: 0.0291
# 6 FOLDS: XGBRegressor RMSE: 0.0293
# 7 FOLDS: XGBRegressor RMSE: 0.0310
# 8 FOLDS: XGBRegressor RMSE: 0.0253
# 9 FOLDS: XGBRegressor RMSE: 0.0280
# 10 FOLDS: XGBRegressor RMSE: 0.0287
#
# XGBRegressor mean RMSE: 0.0315
# ========================================
# LGBMRegressor Cross Validations...:   0%|          | 0/10 [00:00<?, ?it/s]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001507 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1616
# [LightGBM] [Info] Number of data points in the train set: 50613, number of used features: 23
# [LightGBM] [Info] Start training from score 10.637692
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# LGBMRegressor Cross Validations...:  10%|█         | 1/10 [00:04<00:37,  4.19s/it]
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002092 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1617
# [LightGBM] [Info] Number of data points in the train set: 101223, number of used features: 23
# [LightGBM] [Info] Start training from score 10.637229
# LGBMRegressor Cross Validations...:  20%|██        | 2/10 [00:08<00:34,  4.28s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002702 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1625
# [LightGBM] [Info] Number of data points in the train set: 151833, number of used features: 23
# [LightGBM] [Info] Start training from score 10.637213
# LGBMRegressor Cross Validations...:  30%|███       | 3/10 [00:12<00:30,  4.37s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.003403 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1628
# [LightGBM] [Info] Number of data points in the train set: 202443, number of used features: 23
# [LightGBM] [Info] Start training from score 10.637360
# LGBMRegressor Cross Validations...:  40%|████      | 4/10 [00:17<00:26,  4.46s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004015 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1623
# [LightGBM] [Info] Number of data points in the train set: 253053, number of used features: 23
# [LightGBM] [Info] Start training from score 10.638224
# LGBMRegressor Cross Validations...:  50%|█████     | 5/10 [00:22<00:22,  4.55s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.004860 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1624
# [LightGBM] [Info] Number of data points in the train set: 303663, number of used features: 23
# [LightGBM] [Info] Start training from score 10.638410
# LGBMRegressor Cross Validations...:  60%|██████    | 6/10 [00:27<00:18,  4.64s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.005293 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1623
# [LightGBM] [Info] Number of data points in the train set: 354273, number of used features: 23
# [LightGBM] [Info] Start training from score 10.638207
# LGBMRegressor Cross Validations...:  70%|███████   | 7/10 [00:32<00:14,  4.72s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012655 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1622
# [LightGBM] [Info] Number of data points in the train set: 404883, number of used features: 23
# [LightGBM] [Info] Start training from score 10.638405
# LGBMRegressor Cross Validations...:  80%|████████  | 8/10 [00:37<00:09,  4.82s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.006082 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1624
# [LightGBM] [Info] Number of data points in the train set: 455493, number of used features: 23
# [LightGBM] [Info] Start training from score 10.638871
# LGBMRegressor Cross Validations...:  90%|█████████ | 9/10 [00:42<00:04,  4.92s/it]
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.007586 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1624
# [LightGBM] [Info] Number of data points in the train set: 506103, number of used features: 23
# [LightGBM] [Info] Start training from score 10.639103
# LGBMRegressor Cross Validations...: 100%|██████████| 10/10 [00:47<00:00,  4.75s/it]
# 1 FOLDS: LGBMRegressor RMSE: 0.0323
# 2 FOLDS: LGBMRegressor RMSE: 0.0303
# 3 FOLDS: LGBMRegressor RMSE: 0.0314
# 4 FOLDS: LGBMRegressor RMSE: 0.0355
# 5 FOLDS: LGBMRegressor RMSE: 0.0262
# 6 FOLDS: LGBMRegressor RMSE: 0.0261
# 7 FOLDS: LGBMRegressor RMSE: 0.0271
# 8 FOLDS: LGBMRegressor RMSE: 0.0239
# 9 FOLDS: LGBMRegressor RMSE: 0.0257
# 10 FOLDS: LGBMRegressor RMSE: 0.0251
#
# LGBMRegressor mean RMSE: 0.0284
# ========================================

# %%
result_df = pd.DataFrame({'Model': models, 'Score': scores}).reset_index(drop=True)
result_df
# Out:
#                    Model     Score
# 0       LinearRegression  0.017799
# 1                  Ridge  0.017800
# 2                  Lasso  0.058792
# 3             ElasticNet  0.115799
# 4  DecisionTreeRegressor  0.112900
# 5  RandomForestRegressor  0.034481
# 6           XGBRegressor  0.031504
# 7          LGBMRegressor  0.028365

# %%
f, ax = plt.subplots(figsize=(10, 6))
plt.xticks(rotation=90)
sns.barplot(x=result_df['Model'], y=result_df['Score'])
plt.xlabel('Models', fontsize=15)
plt.ylabel('Model Performance', fontsize=15)
plt.ylim(0.0, 0.15)
plt.title('RMSLE', fontsize=15)
plt.show()

# %% [markdown]
# Hyper parameter 튜닝
#
# train데이터를 8:2 비율로 분할하여 학습, 검증에 사용
# 시계열 분석을 위해 데이터 섞이지 않도록 데이터의 마지막 20% 를 사용하게 된다

# %%
cut = int(len(train_set)*0.8)
h_train = train_set[:cut]
h_valid = train_set[cut:]

h_train_X = h_train.drop('transaction_real_price', axis=1)
h_train_y = h_train['transaction_real_price']
h_valid_X = h_valid.drop('transaction_real_price', axis=1)
h_valid_y = h_valid['transaction_real_price']
print(h_train_X.shape, h_train_y.shape, h_valid_X.shape, h_valid_y.shape)
# Out:
# (445370, 23) (445370,) (111343, 23) (111343,)

# %%
h_train_X.head()
# Out:
#         transaction_id  apartment_id  dong  exclusive_use_area  \
# 664659       13.918372           854    55            4.109890
# 716127       13.969474          9210   277            4.454138
# 192609       12.168423          1480    32            4.110185
# 161165       11.990190          6007    64            4.248924
# 7219          8.884610         12110   223            4.814418
#
#         year_of_completion  transaction_year_month  transaction_date  \
# 664659                1989                  201703                 4
# 716127                2013                  201710                 3
# 192609                2000                  201011                 3
# 161165                1987                  201308                 4
# 7219                  1993                  201201                 2
#
#            floor  hangang       CBD  ...  number_of_subway_stations  \
# 664659  1.609438      0.0  0.000000  ...                          8
# 716127  2.397895      0.0  0.000000  ...                         12
# 192609  0.693147      0.0  0.000000  ...                         13
# 161165  2.484907      0.0  0.000000  ...                          3
# 7219    1.386294      0.0  0.693147  ...                         23
#
#         department_stores  day_diff  year  month  age  is_rebuild  \
# 664659           0.000000  2.397895  2017      3   28         0.0
# 716127           0.000000  2.302585  2017     10    4         0.0
# 192609           0.693147  2.302585  2010     11   10         0.0
# 161165           0.000000  2.397895  2013      8   26         0.0
# 7219             0.000000  2.302585  2012      1   19         0.0
#
#         special_high_school  middle_school  elementary_schools
# 664659             0.000000             29                  45
# 716127             0.000000             32                  43
# 192609             0.000000             39                  65
# 161165             0.693147             39                  65
# 7219               0.693147             25                  39
#
# [5 rows x 23 columns]

# %%
def cv_score(model):
    model_name, score = rmse_cv(model)
    print(f'{model_name} 평균 RMSE: {np.mean(score):.4f}')
    return model_name, np.mean(score)

# %%
import timeit
for model in [reg, ridge, lasso, Enet, DTree, rf, model_xgb, model_lgb]:
    start = timeit.default_timer()
    cv_score(model)
    stop = timeit.default_timer()
    print('불러오는데 걸린 시간 : {}초'.format(stop - start))
# Out:
# LinearRegression Cross Validations...: 100%|██████████| 10/10 [00:01<00:00,  5.43it/s]
# LinearRegression 평균 RMSE: 0.0178
# 불러오는데 걸린 시간 : 1.8510880000003453초
# Ridge Cross Validations...: 100%|██████████| 10/10 [00:00<00:00, 13.52it/s]
# Ridge 평균 RMSE: 0.0178
# 불러오는데 걸린 시간 : 0.749203333000878초
# Lasso Cross Validations...: 100%|██████████| 10/10 [00:04<00:00,  2.35it/s]
# Lasso 평균 RMSE: 0.0588
# 불러오는데 걸린 시간 : 4.297367332999784초
# ElasticNet Cross Validations...: 100%|██████████| 10/10 [01:21<00:00,  8.15s/it]
# ElasticNet 평균 RMSE: 0.1158
# 불러오는데 걸린 시간 : 81.59661333299937초
# DecisionTreeRegressor Cross Validations...: 100%|██████████| 10/10 [00:10<00:00,  1.10s/it]
# DecisionTreeRegressor 평균 RMSE: 0.1129
# 불러오는데 걸린 시간 : 10.958202040999822초
# RandomForestRegressor Cross Validations...:  70%|███████   | 7/10 [04:38<02:44, 54.68s/it]

# %%
#여러개의 모델로 만들어진 predict 데이터들의 평균을 구한다.

models = [{'model':model_xgb, 'name':'XGBoost'},
          {'model':model_lgb, 'name':'LightGBM'},
         {'model':rf, 'name' : 'RandomForest'}]

def AveragingBlending(models, x, y, sub_x):
    for m in models : 
        m['model'].fit(x.values, y)
    
    predictions = np.column_stack([m['model'].predict(sub_x.values) for m in models])
    return predictions
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 #여러개의 모델로 만들어진 predict 데이터들의 평균을 구한다.
# ----> 3 models = [{'model':model_xgb, 'name':'XGBoost'},
#       4           {'model':model_lgb, 'name':'LightGBM'},
#       5          {'model':rf, 'name' : 'RandomForest'}]
#       7 def AveragingBlending(models, x, y, sub_x):
#       8     for m in models :
#
# NameError: name 'model_xgb' is not defined

# %%
start = timeit.default_timer()

y_test_pred = AveragingBlending(models, train, target, test)
y_test_pred = (y_test_pred[:, 0]*0.05 + y_test_pred[:, 1]*0.1 + y_test_pred[:, 2]*0.85)
predictions = y_test_pred

stop = timeit.default_timer()
print('불러오는데 걸린 시간 : {}초'.format(stop - start))
